# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires keras>=3.2.0, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Collecting keras>=3.2.0 (from tensorflow)
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Norte']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-12-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-13-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao Região  \
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0  Norte
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0  Norte
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0  Norte
# 3                       2    2010-01-01  AC          BUJARI     8838.0  Norte
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0  Norte
# ...                   ...           ...  ..             ...        ...    ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0  Norte
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0  Norte
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0  Norte
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0  Norte
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0  Norte
#
#          taxa_internacao             Porte
# 0               1.070255   Pequeno Porte I
# 1               1.104972   Pequeno Porte I
# 2               2.150056  Pequeno Porte II
# 3               0.226296   Pequeno Porte I
# 4               0.435777   Pequeno Porte I
# ...                  ...               ...
# 1024875         1.212016  Pequeno Porte II
# 1024876         0.621891   Pequeno Porte I
# 1024877         0.466853   Pequeno Porte I
# 1024878         1.069900   Pequeno Porte I
# 1024879         1.790434   Pequeno Porte I
#
# [82800 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Médio Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF        Município  populacao  \
# 5                     249    2010-01-01  AC  CRUZEIRO DO SUL    81907.0
# 143                    48    2010-01-01  AM            COARI    77473.0
# 152                   122    2010-01-01  AM      ITACOATIARA    88563.0
# 159                    91    2010-01-01  AM       MANACAPURU    86831.0
# 164                    24    2010-01-01  AM            MAUÉS    53273.0
# ...                   ...           ...  ..              ...        ...
# 1023184                 7    2024-04-01  RO             JARU    53211.0
# 1023202                15    2024-04-01  RO   ROLIM DE MOURA    51822.0
# 1023213                10    2024-04-01  RO          VILHENA    77969.0
# 1024799                75    2024-04-01  TO           GURUPI    78394.0
# 1024845                56    2024-04-01  TO   PORTO NACIONAL    50196.0
#
#         Região  taxa_internacao        Porte
# 5        Norte         3.040033  Médio Porte
# 143      Norte         0.619571  Médio Porte
# 152      Norte         1.377550  Médio Porte
# 159      Norte         1.048013  Médio Porte
# 164      Norte         0.450510  Médio Porte
# ...        ...              ...          ...
# 1023184  Norte         0.131552  Médio Porte
# 1023202  Norte         0.289452  Médio Porte
# 1023213  Norte         0.128256  Médio Porte
# 1024799  Norte         0.956706  Médio Porte
# 1024845  Norte         1.115627  Médio Porte
#
# [7320 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-17-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.921641
# 2010-02-28            1.926065
# 2010-03-31            1.949652
# 2010-04-30            1.866605
# 2010-05-31            1.905196
# ...                        ...
# 2023-12-31            1.183333
# 2024-01-31            1.124234
# 2024-02-29            1.080866
# 2024-03-31            1.074505
# 2024-04-30            0.759031
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.921641
# 2010-02-28            1.926065
# 2010-03-31            1.949652
# 2010-04-30            1.866605
# 2010-05-31            1.905196
# ...                        ...
# 2023-12-31            1.183333
# 2024-01-31            1.124234
# 2024-02-29            1.080866
# 2024-03-31            1.074505
# 2024-04-30            0.759031
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 405ms/step - loss: 0.2318 - mean_squared_error: 0.2318
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0569 - mean_squared_error: 0.0569
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 448ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 414ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 429ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - loss: 0.0281 - mean_squared_error: 0.0281
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 293ms/step - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 487ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 278ms/step - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 436ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 327ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 454ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 448ms/step - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 445ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 456ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 298ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 440ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 455ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 306ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 437ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 460ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 508ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 465ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 310ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 471ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 341ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 480ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 425ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 308ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 438ms/step - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 481ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 509ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 319ms/step - loss: 0.0063 - mean_squared_error: 0.0063

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.917994    0.951922
# 2022-02-28  0.910172    0.935405
# 2022-03-31  0.910738    1.044596
# 2022-04-30  0.940786    1.173183
# 2022-05-31  1.012052    1.176109
# 2022-06-30  1.082111    1.138536
# 2022-07-31  1.111906    1.078325
# 2022-08-31  1.093636    1.069318
# 2022-09-30  1.059266    1.056314
# 2022-10-31  1.033742    1.131829
# 2022-11-30  1.044467    1.114472
# 2022-12-31  1.069296    1.063065
# 2023-01-31  1.076105    1.159152
# 2023-02-28  1.087210    1.094034
# 2023-03-31  1.092288    1.166146
# 2023-04-30  1.104013    1.251972
# 2023-05-31  1.138237    1.257126
# 2023-06-30  1.177599    1.179916
# 2023-07-31  1.184479    1.185056
# 2023-08-31  1.168537    1.191718
# 2023-09-30  1.154156    1.170180
# 2023-10-31  1.147097    1.186146
# 2023-11-30  1.148161    1.272708
# 2023-12-31  1.174373    1.183333
# 2024-01-31  1.188594    1.124234
# 2024-02-29  1.167039    1.080866
# 2024-03-31  1.125100    1.074504
# 2024-04-30  1.087889    0.759031

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.01102564

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.10500305

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 1.2487711995355353

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_medio_porte_sem_dados_inputados(2010)_norte.csv', index=False)
