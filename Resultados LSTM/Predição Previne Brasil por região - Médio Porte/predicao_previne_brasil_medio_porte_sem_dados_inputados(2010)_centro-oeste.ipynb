# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.9 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires keras>=3.2.0, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Collecting keras>=3.2.0 (from tensorflow)
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.0 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Centro-Oeste']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-12-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-13-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF                         Município  \
# 803                  2464    2010-01-01  DF                  DISTRITO FEDERAL
# 882                     5    2010-01-01  GO                   ABADIA DE GOIÁS
# 883                    12    2010-01-01  GO                         ABADIÂNIA
# 884                    37    2010-01-01  GO                           ACREÚNA
# 885                     0    2010-01-01  GO                         ADELÂNDIA
# ...                   ...           ...  ..                               ...
# 1021723                 2    2024-04-01  MT              VALE DE SÃO DOMINGOS
# 1021724               224    2024-04-01  MT                     VÁRZEA GRANDE
# 1021725                 5    2024-04-01  MT                              VERA
# 1021726                 2    2024-04-01  MT  VILA BELA DA SANTÍSSIMA TRINDADE
# 1021727                 3    2024-04-01  MT                         VILA RICA
#
#          populacao        Região  taxa_internacao             Porte
# 803            NaN  Centro-Oeste              NaN              None
# 882         7000.0  Centro-Oeste         0.714286   Pequeno Porte I
# 883        16040.0  Centro-Oeste         0.748130   Pequeno Porte I
# 884        20644.0  Centro-Oeste         1.792288  Pequeno Porte II
# 885         2522.0  Centro-Oeste         0.000000   Pequeno Porte I
# ...            ...           ...              ...               ...
# 1021723     3124.0  Centro-Oeste         0.640205   Pequeno Porte I
# 1021724   258537.0  Centro-Oeste         0.866414      Grande Porte
# 1021725    10476.0  Centro-Oeste         0.477281   Pequeno Porte I
# 1021726    14834.0  Centro-Oeste         0.134825   Pequeno Porte I
# 1021727    21885.0  Centro-Oeste         0.137080  Pequeno Porte II
#
# [85928 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Médio Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF           Município  populacao  \
# 929                    52    2010-01-01  GO        CALDAS NOVAS    71741.0
# 940                    93    2010-01-01  GO             CATALÃO    88206.0
# 946                    37    2010-01-01  GO    CIDADE OCIDENTAL    56921.0
# 975                   142    2010-01-01  GO           GOIANÉSIA    60620.0
# 1005                   39    2010-01-01  GO           ITUMBIARA    94554.0
# ...                   ...           ...  ..                 ...        ...
# 1021603                 5    2024-04-01  MT     BARRA DO GARÇAS    57890.0
# 1021606                62    2024-04-01  MT             CÁCERES    90011.0
# 1021689                39    2024-04-01  MT  PRIMAVERA DO LESTE    53291.0
# 1021715                64    2024-04-01  MT             SORRISO    68086.0
# 1021717                 4    2024-04-01  MT    TANGARÁ DA SERRA    85393.0
#
#                Região  taxa_internacao        Porte
# 929      Centro-Oeste         0.724830  Médio Porte
# 940      Centro-Oeste         1.054350  Médio Porte
# 946      Centro-Oeste         0.650024  Médio Porte
# 975      Centro-Oeste         2.342461  Médio Porte
# 1005     Centro-Oeste         0.412463  Médio Porte
# ...               ...              ...          ...
# 1021603  Centro-Oeste         0.086371  Médio Porte
# 1021606  Centro-Oeste         0.688805  Médio Porte
# 1021689  Centro-Oeste         0.731831  Médio Porte
# 1021715  Centro-Oeste         0.939988  Médio Porte
# 1021717  Centro-Oeste         0.046842  Médio Porte
#
# [3348 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-17-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262137
# 2010-02-28            1.234223
# 2010-03-31            1.277844
# 2010-04-30            1.268712
# 2010-05-31            1.237561
# ...                        ...
# 2023-12-31            0.777097
# 2024-01-31            0.724865
# 2024-02-29            0.757162
# 2024-03-31            0.798466
# 2024-04-30            0.736952
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262137
# 2010-02-28            1.234223
# 2010-03-31            1.277844
# 2010-04-30            1.268712
# 2010-05-31            1.237561
# ...                        ...
# 2023-12-31            0.777097
# 2024-01-31            0.724865
# 2024-02-29            0.757162
# 2024-03-31            0.798466
# 2024-04-30            0.736952
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - loss: 0.1547 - mean_squared_error: 0.1547
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.0790 - mean_squared_error: 0.0790
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - loss: 0.0272 - mean_squared_error: 0.0272
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - loss: 0.0264 - mean_squared_error: 0.0264
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 400ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 308ms/step - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 401ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 325ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - loss: 0.0177 - mean_squared_error: 0.0177
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 395ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 339ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 445ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 450ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 444ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 403ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 406ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 399ms/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 258ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 405ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.0088 - mean_squared_error: 0.0088

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.666082    0.801302
# 2022-02-28  0.707589    0.622357
# 2022-03-31  0.681460    0.704556
# 2022-04-30  0.657040    0.817007
# 2022-05-31  0.712121    0.770014
# 2022-06-30  0.758757    0.695743
# 2022-07-31  0.731343    0.800459
# 2022-08-31  0.729872    0.827174
# 2022-09-30  0.772830    0.763660
# 2022-10-31  0.782210    0.786422
# 2022-11-30  0.770710    0.731654
# 2022-12-31  0.745986    0.662467
# 2023-01-31  0.705339    0.790717
# 2023-02-28  0.731088    0.802879
# 2023-03-31  0.786137    0.832260
# 2023-04-30  0.816559    0.836373
# 2023-05-31  0.816254    0.864863
# 2023-06-30  0.820320    0.807847
# 2023-07-31  0.810165    0.833052
# 2023-08-31  0.805908    0.796703
# 2023-09-30  0.798495    0.828093
# 2023-10-31  0.805260    0.728548
# 2023-11-30  0.778388    0.742702
# 2023-12-31  0.753685    0.777097
# 2024-01-31  0.766918    0.724865
# 2024-02-29  0.767831    0.757162
# 2024-03-31  0.765985    0.798466
# 2024-04-30  0.781484    0.736952

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.004051234

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.063649304

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 0.859949345941628

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_medio_porte_sem_dados_inputados(2010)_centro-oeste.csv', index=False)
