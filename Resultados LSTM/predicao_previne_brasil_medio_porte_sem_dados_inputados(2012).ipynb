# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires keras>=3.2.0, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Collecting keras>=3.2.0 (from tensorflow)
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao  \
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
#          taxa_internacao             Porte
# 0               1.070255   Pequeno Porte I
# 1               1.104972   Pequeno Porte I
# 2               2.150056  Pequeno Porte II
# 3               0.226296   Pequeno Porte I
# 4               0.435777   Pequeno Porte I
# ...                  ...               ...
# 1024875         1.212016  Pequeno Porte II
# 1024876         0.621891   Pequeno Porte I
# 1024877         0.466853   Pequeno Porte I
# 1024878         1.069900   Pequeno Porte I
# 1024879         1.790434   Pequeno Porte I
#
# [1024880 rows x 7 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Médio Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF            Município  populacao  \
# 5                     249    2010-01-01  AC      CRUZEIRO DO SUL    81907.0
# 36                     54    2010-01-01  AL         CAMPO ALEGRE    52041.0
# 45                     55    2010-01-01  AL             CORURIPE    53387.0
# 88                     64    2010-01-01  AL  PALMEIRA DOS ÍNDIOS    72064.0
# 94                    138    2010-01-01  AL               PENEDO    61834.0
# ...                   ...           ...  ..                  ...        ...
# 1024719               133    2024-04-01  SP              UBATUBA    80781.0
# 1024734                59    2024-04-01  SP              VINHEDO    65209.0
# 1024739                69    2024-04-01  SP          VOTUPORANGA    86820.0
# 1024799                75    2024-04-01  TO               GURUPI    78394.0
# 1024845                56    2024-04-01  TO       PORTO NACIONAL    50196.0
#
#          taxa_internacao        Porte
# 5               3.040033  Médio Porte
# 36              1.037643  Médio Porte
# 45              1.030213  Médio Porte
# 88              0.888099  Médio Porte
# 94              2.231782  Médio Porte
# ...                  ...          ...
# 1024719         1.646427  Médio Porte
# 1024734         0.904783  Médio Porte
# 1024739         0.794748  Médio Porte
# 1024799         0.956706  Médio Porte
# 1024845         1.115627  Médio Porte
#
# [58368 rows x 7 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-15-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262302
# 2010-02-28            1.205797
# 2010-03-31            1.276683
# 2010-04-30            1.215884
# 2010-05-31            1.215052
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2012-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2012-01-31            1.094733
# 2012-02-29            1.062539
# 2012-03-31            1.125141
# 2012-04-30            1.112374
# 2012-05-31            1.109910
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [148 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 136

# %%
x_train, y_train = x[:108], y[:108]
x_test, y_test = x[108:], y[108:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - loss: 0.3057 - mean_squared_error: 0.3057
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - loss: 0.2164 - mean_squared_error: 0.2164
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 453ms/step - loss: 0.0584 - mean_squared_error: 0.0584
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 527ms/step - loss: 0.0503 - mean_squared_error: 0.0503
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 355ms/step - loss: 0.0320 - mean_squared_error: 0.0320
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - loss: 0.0290 - mean_squared_error: 0.0290
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 395ms/step - loss: 0.0265 - mean_squared_error: 0.0265
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 655ms/step - loss: 0.0257 - mean_squared_error: 0.0257
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - loss: 0.0248 - mean_squared_error: 0.0248
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - loss: 0.0211 - mean_squared_error: 0.0211
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 492ms/step - loss: 0.0225 - mean_squared_error: 0.0225
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - loss: 0.0195 - mean_squared_error: 0.0195
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - loss: 0.0208 - mean_squared_error: 0.0208
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 479ms/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - loss: 0.0223 - mean_squared_error: 0.0223
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 324ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 394ms/step - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - loss: 0.0177 - mean_squared_error: 0.0177
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - loss: 0.0220 - mean_squared_error: 0.0220
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 336ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 470ms/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 471ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - loss: 0.0225 - mean_squared_error: 0.0225
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 346ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 479ms/step - loss: 0.0221 - mean_squared_error: 0.0221
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 440ms/step - loss: 0.0246 - mean_squared_error: 0.0246
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 378ms/step - loss: 0.0219 - mean_squared_error: 0.0219
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - loss: 0.0213 - mean_squared_error: 0.0213
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - loss: 0.0255 - mean_squared_error: 0.0255
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - loss: 0.0304 - mean_squared_error: 0.0304
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 333ms/step - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 502ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 439ms/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 311ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - loss: 0.0180 - mean_squared_error: 0.0180
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 479ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step - loss: 0.0229 - mean_squared_error: 0.0229
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 509ms/step - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 423ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 501ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 327ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 414ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 319ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 474ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 511ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 345ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 432ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 553ms/step - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 367ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 406ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 325ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 322ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 513ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 315ms/step - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 321ms/step - loss: 0.0104 - mean_squared_error: 0.0104

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.743085    0.806979
# 2022-02-28  0.762002    0.738610
# 2022-03-31  0.769261    0.846133
# 2022-04-30  0.784378    0.867756
# 2022-05-31  0.816918    0.917178
# 2022-06-30  0.861369    0.911903
# 2022-07-31  0.892992    0.917154
# 2022-08-31  0.900404    0.939364
# 2022-09-30  0.897387    0.908139
# 2022-10-31  0.892540    0.906842
# 2022-11-30  0.891760    0.887028
# 2022-12-31  0.892035    0.870371
# 2023-01-31  0.888547    0.877790
# 2023-02-28  0.884504    0.857721
# 2023-03-31  0.880873    0.924976
# 2023-04-30  0.893188    0.931383
# 2023-05-31  0.916046    0.992631
# 2023-06-30  0.945798    0.975985
# 2023-07-31  0.965456    0.989791
# 2023-08-31  0.970174    0.963418
# 2023-09-30  0.960298    0.922492
# 2023-10-31  0.939306    0.923246
# 2023-11-30  0.922159    0.921506
# 2023-12-31  0.919703    0.890539
# 2024-01-31  0.922502    0.890174
# 2024-02-29  0.921520    0.848012
# 2024-03-31  0.906447    0.911118
# 2024-04-30  0.898656    0.839982

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.0020397322

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.045163393

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 1.047664545022267

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_medio_porte_sem_dados_inputados(2012).csv', index=False)
