# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Requirement already satisfied: scikeras==0.12.0 in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Collecting keras>=3.2.0 (from tensorflow)
#   Using cached keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Using cached keras-3.5.0-py3-none-any.whl (1.1 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Centro-Oeste']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-12-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-13-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF                         Município  \
# 803                  2464    2010-01-01  DF                  DISTRITO FEDERAL
# 882                     5    2010-01-01  GO                   ABADIA DE GOIÁS
# 883                    12    2010-01-01  GO                         ABADIÂNIA
# 884                    37    2010-01-01  GO                           ACREÚNA
# 885                     0    2010-01-01  GO                         ADELÂNDIA
# ...                   ...           ...  ..                               ...
# 1021723                 2    2024-04-01  MT              VALE DE SÃO DOMINGOS
# 1021724               224    2024-04-01  MT                     VÁRZEA GRANDE
# 1021725                 5    2024-04-01  MT                              VERA
# 1021726                 2    2024-04-01  MT  VILA BELA DA SANTÍSSIMA TRINDADE
# 1021727                 3    2024-04-01  MT                         VILA RICA
#
#          populacao        Região  taxa_internacao             Porte
# 803            NaN  Centro-Oeste              NaN              None
# 882         7000.0  Centro-Oeste         0.714286   Pequeno Porte I
# 883        16040.0  Centro-Oeste         0.748130   Pequeno Porte I
# 884        20644.0  Centro-Oeste         1.792288  Pequeno Porte II
# 885         2522.0  Centro-Oeste         0.000000   Pequeno Porte I
# ...            ...           ...              ...               ...
# 1021723     3124.0  Centro-Oeste         0.640205   Pequeno Porte I
# 1021724   258537.0  Centro-Oeste         0.866414      Grande Porte
# 1021725    10476.0  Centro-Oeste         0.477281   Pequeno Porte I
# 1021726    14834.0  Centro-Oeste         0.134825   Pequeno Porte I
# 1021727    21885.0  Centro-Oeste         0.137080  Pequeno Porte II
#
# [85928 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Grande Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF              Município  populacao  \
# 888                   108    2010-01-01  GO  ÁGUAS LINDAS DE GOIÁS   162245.0
# 897                   607    2010-01-01  GO               ANÁPOLIS   340632.0
# 900                   438    2010-01-01  GO   APARECIDA DE GOIÂNIA   463854.0
# 970                   105    2010-01-01  GO                FORMOSA   101885.0
# 1016                   84    2010-01-01  GO               LUZIÂNIA   177671.0
# ...                   ...           ...  ..                    ...        ...
# 1021585               158    2024-04-01  MS            TRÊS LAGOAS   103691.0
# 1021624               242    2024-04-01  MT                 CUIABÁ   564062.0
# 1021696               186    2024-04-01  MT           RONDONÓPOLIS   200074.0
# 1021714                44    2024-04-01  MT                  SINOP   115759.0
# 1021724               224    2024-04-01  MT          VÁRZEA GRANDE   258537.0
#
#                Região  taxa_internacao         Porte
# 888      Centro-Oeste         0.665660  Grande Porte
# 897      Centro-Oeste         1.781982  Grande Porte
# 900      Centro-Oeste         0.944263  Grande Porte
# 970      Centro-Oeste         1.030574  Grande Porte
# 1016     Centro-Oeste         0.472784  Grande Porte
# ...               ...              ...           ...
# 1021585  Centro-Oeste         1.523758  Grande Porte
# 1021624  Centro-Oeste         0.429031  Grande Porte
# 1021696  Centro-Oeste         0.929656  Grande Porte
# 1021714  Centro-Oeste         0.380100  Grande Porte
# 1021724  Centro-Oeste         0.866414  Grande Porte
#
# [3184 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-17-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.097339
# 2010-02-28            1.043002
# 2010-03-31            1.017372
# 2010-04-30            0.990271
# 2010-05-31            0.999323
# ...                        ...
# 2023-12-31            0.770411
# 2024-01-31            0.770887
# 2024-02-29            0.739992
# 2024-03-31            0.781407
# 2024-04-30            0.771353
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.097339
# 2010-02-28            1.043002
# 2010-03-31            1.017372
# 2010-04-30            0.990271
# 2010-05-31            0.999323
# ...                        ...
# 2023-12-31            0.770411
# 2024-01-31            0.770887
# 2024-02-29            0.739992
# 2024-03-31            0.781407
# 2024-04-30            0.771353
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 333ms/step - loss: 0.1476 - mean_squared_error: 0.1476
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 330ms/step - loss: 0.0802 - mean_squared_error: 0.0802
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 370ms/step - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 337ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 406ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 462ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 354ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 448ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - loss: 0.0147 - mean_squared_error: 0.0147
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - loss: 0.0136 - mean_squared_error: 0.0136
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 372ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 471ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 502ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 360ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 509ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 459ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 440ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 462ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 369ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 326ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - loss: 0.0136 - mean_squared_error: 0.0136
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 305ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 437ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 452ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 308ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 315ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 500ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 311ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 478ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 387ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 517ms/step - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 451ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 304ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 387ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 485ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 448ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 320ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 429ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 363ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 349ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 400ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 479ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 316ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 477ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 320ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 520ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 401ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 499ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 522ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 382ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 474ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 456ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 489ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 328ms/step - loss: 0.0067 - mean_squared_error: 0.0067

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 689ms/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.511637    0.612279
# 2022-02-28  0.571223    0.558587
# 2022-03-31  0.594874    0.677755
# 2022-04-30  0.635682    0.704669
# 2022-05-31  0.693139    0.766824
# 2022-06-30  0.742412    0.735101
# 2022-07-31  0.742131    0.707964
# 2022-08-31  0.714595    0.738084
# 2022-09-30  0.721680    0.715456
# 2022-10-31  0.729104    0.762350
# 2022-11-30  0.750960    0.684364
# 2022-12-31  0.730398    0.693988
# 2023-01-31  0.713443    0.722758
# 2023-02-28  0.736163    0.775326
# 2023-03-31  0.785251    0.864018
# 2023-04-30  0.848008    0.872828
# 2023-05-31  0.873815    0.876175
# 2023-06-30  0.866705    0.810641
# 2023-07-31  0.826410    0.847502
# 2023-08-31  0.827369    0.833445
# 2023-09-30  0.838802    0.777225
# 2023-10-31  0.808497    0.764332
# 2023-11-30  0.783155    0.789817
# 2023-12-31  0.804281    0.770411
# 2024-01-31  0.813482    0.770887
# 2024-02-29  0.806693    0.739992
# 2024-03-31  0.788653    0.781407
# 2024-04-30  0.801948    0.771353

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.002224317

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.047162667

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 0.9092943034786741

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_grande_porte_sem_dados_inputados(2010)_centro-oeste.csv', index=False)
