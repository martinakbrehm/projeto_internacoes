# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Sudeste']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-12-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-13-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF             Município  populacao  \
# 804                    47    2010-01-01  ES        AFONSO CLÁUDIO    31808.0
# 805                     2    2010-01-01  ES    ÁGUA DOCE DO NORTE    12043.0
# 806                     0    2010-01-01  ES          ÁGUIA BRANCA     9739.0
# 807                    46    2010-01-01  ES                ALEGRE    31478.0
# 808                     4    2010-01-01  ES        ALFREDO CHAVES    14277.0
# ...                   ...           ...  ..                   ...        ...
# 1024736                 6    2024-04-01  SP  VISTA ALEGRE DO ALTO     7059.0
# 1024737                 2    2024-04-01  SP        VITÓRIA BRASIL     1781.0
# 1024738                81    2024-04-01  SP            VOTORANTIM   111543.0
# 1024739                69    2024-04-01  SP           VOTUPORANGA    86820.0
# 1024740                 5    2024-04-01  SP              ZACARIAS     2394.0
#
#           Região  taxa_internacao             Porte
# 804      Sudeste         1.477616  Pequeno Porte II
# 805      Sudeste         0.166072   Pequeno Porte I
# 806      Sudeste         0.000000   Pequeno Porte I
# 807      Sudeste         1.461338  Pequeno Porte II
# 808      Sudeste         0.280171   Pequeno Porte I
# ...          ...              ...               ...
# 1024736  Sudeste         0.849979   Pequeno Porte I
# 1024737  Sudeste         1.122965   Pequeno Porte I
# 1024738  Sudeste         0.726177      Grande Porte
# 1024739  Sudeste         0.794748       Médio Porte
# 1024740  Sudeste         2.088555   Pequeno Porte I
#
# [306912 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Grande Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF                Município  \
# 819                   223    2010-01-01  ES  CACHOEIRO DE ITAPEMIRIM
# 820                   138    2010-01-01  ES                CARIACICA
# 822                    97    2010-01-01  ES                 COLATINA
# 832                   191    2010-01-01  ES                GUARAPARI
# 846                   128    2010-01-01  ES                 LINHARES
# ...                   ...           ...  ..                      ...
# 1024701                56    2024-04-01  SP                    TATUÍ
# 1024702                39    2024-04-01  SP                  TAUBATÉ
# 1024727                52    2024-04-01  SP                 VALINHOS
# 1024732                42    2024-04-01  SP          VÁRZEA PAULISTA
# 1024738                81    2024-04-01  SP               VOTORANTIM
#
#          populacao   Região  taxa_internacao         Porte
# 819       194271.0  Sudeste         1.147881  Grande Porte
# 820       356785.0  Sudeste         0.386788  Grande Porte
# 822       114367.0  Sudeste         0.848147  Grande Porte
# 832       107715.0  Sudeste         1.773198  Grande Porte
# 846       144567.0  Sudeste         0.885403  Grande Porte
# ...            ...      ...              ...           ...
# 1024701   110023.0  Sudeste         0.508984  Grande Porte
# 1024702   285688.0  Sudeste         0.136513  Grande Porte
# 1024727   109476.0  Sudeste         0.474990  Grande Porte
# 1024732   109780.0  Sudeste         0.382583  Grande Porte
# 1024738   111543.0  Sudeste         0.726177  Grande Porte
#
# [23664 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-17-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.723116
# 2010-02-28            0.695710
# 2010-03-31            0.752353
# 2010-04-30            0.759095
# 2010-05-31            0.742933
# ...                        ...
# 2023-12-31            0.763513
# 2024-01-31            0.756618
# 2024-02-29            0.755385
# 2024-03-31            0.791629
# 2024-04-30            0.802682
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.723116
# 2010-02-28            0.695710
# 2010-03-31            0.752353
# 2010-04-30            0.759095
# 2010-05-31            0.742933
# ...                        ...
# 2023-12-31            0.763513
# 2024-01-31            0.756618
# 2024-02-29            0.755385
# 2024-03-31            0.791629
# 2024-04-30            0.802682
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 12s 285ms/step - loss: 0.1115 - mean_squared_error: 0.1115
# Epoch 2/100
# 9/9 [==============================] - 3s 314ms/step - loss: 0.0521 - mean_squared_error: 0.0521
# Epoch 3/100
# 9/9 [==============================] - 4s 425ms/step - loss: 0.0196 - mean_squared_error: 0.0196
# Epoch 4/100
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 5/100
# 9/9 [==============================] - 3s 285ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 6/100
# 9/9 [==============================] - 3s 279ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 7/100
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 8/100
# 9/9 [==============================] - 4s 429ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 9/100
# 9/9 [==============================] - 3s 355ms/step - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 10/100
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 11/100
# 9/9 [==============================] - 3s 277ms/step - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 12/100
# 9/9 [==============================] - 3s 279ms/step - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 13/100
# 9/9 [==============================] - 4s 405ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 14/100
# 9/9 [==============================] - 4s 392ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 15/100
# 9/9 [==============================] - 3s 285ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 16/100
# 9/9 [==============================] - 2s 276ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 17/100
# 9/9 [==============================] - 3s 279ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 18/100
# 9/9 [==============================] - 3s 322ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 19/100
# 9/9 [==============================] - 4s 446ms/step - loss: 0.0211 - mean_squared_error: 0.0211
# Epoch 20/100
# 9/9 [==============================] - 3s 274ms/step - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 21/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 22/100
# 9/9 [==============================] - 3s 276ms/step - loss: 0.0189 - mean_squared_error: 0.0189
# Epoch 23/100
# 9/9 [==============================] - 3s 292ms/step - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 24/100
# 9/9 [==============================] - 4s 442ms/step - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 25/100
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0147 - mean_squared_error: 0.0147
# Epoch 26/100
# 9/9 [==============================] - 3s 280ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 27/100
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 28/100
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 29/100
# 9/9 [==============================] - 3s 386ms/step - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 30/100
# 9/9 [==============================] - 3s 378ms/step - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 31/100
# 9/9 [==============================] - 2s 272ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 32/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 33/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 34/100
# 9/9 [==============================] - 3s 277ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 35/100
# 9/9 [==============================] - 4s 403ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 36/100
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 37/100
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 38/100
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 39/100
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 40/100
# 9/9 [==============================] - 3s 337ms/step - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 41/100
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 42/100
# 9/9 [==============================] - 2s 264ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 43/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 44/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 45/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 46/100
# 9/9 [==============================] - 3s 380ms/step - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 47/100
# 9/9 [==============================] - 3s 346ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 48/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 49/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 50/100
# 9/9 [==============================] - 2s 277ms/step - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 51/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 52/100
# 9/9 [==============================] - 4s 409ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 53/100
# 9/9 [==============================] - 3s 273ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 54/100
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 55/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 56/100
# 9/9 [==============================] - 2s 274ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 57/100
# 9/9 [==============================] - 3s 372ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 58/100
# 9/9 [==============================] - 3s 360ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 59/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 60/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 61/100
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 62/100
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 63/100
# 9/9 [==============================] - 4s 419ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 64/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 65/100
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 66/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 67/100
# 9/9 [==============================] - 2s 277ms/step - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 68/100
# 9/9 [==============================] - 3s 363ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 69/100
# 9/9 [==============================] - 4s 457ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 70/100
# 9/9 [==============================] - 3s 338ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 71/100
# 9/9 [==============================] - 3s 366ms/step - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 72/100
# 9/9 [==============================] - 3s 387ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 73/100
# 9/9 [==============================] - 4s 431ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 74/100
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 75/100
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 76/100
# 9/9 [==============================] - 2s 275ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 77/100
# 9/9 [==============================] - 3s 286ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 78/100
# 9/9 [==============================] - 4s 403ms/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 79/100
# 9/9 [==============================] - 3s 373ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 80/100
# 9/9 [==============================] - 3s 275ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 81/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 82/100
# 9/9 [==============================] - 3s 286ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 83/100
# 9/9 [==============================] - 3s 351ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 84/100
# 9/9 [==============================] - 4s 424ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 85/100
# 9/9 [==============================] - 3s 292ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 86/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 87/100
# 9/9 [==============================] - 3s 283ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 88/100
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 89/100
# 9/9 [==============================] - 4s 435ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 90/100
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 91/100
# 9/9 [==============================] - 3s 282ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 92/100
# 9/9 [==============================] - 3s 277ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 93/100
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 94/100
# 9/9 [==============================] - 4s 439ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 95/100
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 96/100
# 9/9 [==============================] - 3s 284ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 97/100
# 9/9 [==============================] - 2s 276ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 98/100
# 9/9 [==============================] - 3s 282ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 99/100
# 9/9 [==============================] - 3s 383ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 100/100
# 9/9 [==============================] - 4s 396ms/step - loss: 0.0052 - mean_squared_error: 0.0052

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.609500    0.713363
# 2022-02-28  0.656703    0.625724
# 2022-03-31  0.638561    0.717863
# 2022-04-30  0.645108    0.739540
# 2022-05-31  0.676204    0.783290
# 2022-06-30  0.711447    0.741871
# 2022-07-31  0.705264    0.767923
# 2022-08-31  0.699553    0.782146
# 2022-09-30  0.709846    0.787605
# 2022-10-31  0.723735    0.766255
# 2022-11-30  0.721767    0.734179
# 2022-12-31  0.704241    0.732987
# 2023-01-31  0.697907    0.725996
# 2023-02-28  0.701257    0.726888
# 2023-03-31  0.712040    0.810652
# 2023-04-30  0.757228    0.800780
# 2023-05-31  0.778202    0.836774
# 2023-06-30  0.785899    0.832991
# 2023-07-31  0.781951    0.811469
# 2023-08-31  0.763563    0.838643
# 2023-09-30  0.764199    0.771626
# 2023-10-31  0.741366    0.775959
# 2023-11-30  0.729868    0.758888
# 2023-12-31  0.728981    0.763513
# 2024-01-31  0.738535    0.756618
# 2024-02-29  0.745867    0.755385
# 2024-03-31  0.749010    0.791629
# 2024-04-30  0.765281    0.802682

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.0032525635

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.05703125

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 1.3910015549445314

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_grande_porte_sem_dados_inputados(2010)_sudeste.csv', index=False)
