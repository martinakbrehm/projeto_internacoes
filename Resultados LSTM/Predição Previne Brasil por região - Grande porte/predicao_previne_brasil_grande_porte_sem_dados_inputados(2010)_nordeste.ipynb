# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Requirement already satisfied: scikeras==0.12.0 in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Collecting keras==2.15.0
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires keras>=3.2.0, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Collecting keras>=3.2.0 (from tensorflow)
#   Using cached keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Using cached keras-3.5.0-py3-none-any.whl (1.1 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Nordeste']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-15-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-16-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF               Município  \
# 22                     17    2010-01-01  AL             ÁGUA BRANCA
# 23                     23    2010-01-01  AL                  ANADIA
# 24                    395    2010-01-01  AL               ARAPIRACA
# 25                     25    2010-01-01  AL                 ATALAIA
# 26                     14    2010-01-01  AL  BARRA DE SANTO ANTÔNIO
# ...                   ...           ...  ..                     ...
# 1024091                 6    2024-04-01  SE                  SIRIRI
# 1024092                 1    2024-04-01  SE                   TELHA
# 1024093                 9    2024-04-01  SE          TOBIAS BARRETO
# 1024094                 6    2024-04-01  SE           TOMAR DO GERU
# 1024095                12    2024-04-01  SE                 UMBAÚBA
#
#          populacao    Região  taxa_internacao             Porte
# 22         19844.0  Nordeste         0.856682   Pequeno Porte I
# 23         17844.0  Nordeste         1.288949   Pequeno Porte I
# 24        219165.0  Nordeste         1.802295      Grande Porte
# 25         45390.0  Nordeste         0.550782  Pequeno Porte II
# 26         14573.0  Nordeste         0.960681   Pequeno Porte I
# ...            ...       ...              ...               ...
# 1024091     8160.0  Nordeste         0.735294   Pequeno Porte I
# 1024092     3015.0  Nordeste         0.331675   Pequeno Porte I
# 1024093    48976.0  Nordeste         0.183763  Pequeno Porte II
# 1024094    13105.0  Nordeste         0.457841   Pequeno Porte I
# 1024095    22871.0  Nordeste         0.524682  Pequeno Porte II
#
# [330096 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Grande Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF                 Município  \
# 24                    395    2010-01-01  AL                 ARAPIRACA
# 208                   104    2010-01-01  BA                ALAGOINHAS
# 239                   296    2010-01-01  BA                 BARREIRAS
# 271                    77    2010-01-01  BA                  CAMAÇARI
# 329                    72    2010-01-01  BA                 EUNÁPOLIS
# ...                   ...           ...  ..                       ...
# 1023081                58    2024-04-01  RN                   MOSSORÓ
# 1023082               338    2024-04-01  RN                     NATAL
# 1023091                33    2024-04-01  RN                PARNAMIRIM
# 1024023               247    2024-04-01  SE                   ARACAJU
# 1024067                76    2024-04-01  SE  NOSSA SENHORA DO SOCORRO
#
#          populacao    Região  taxa_internacao         Porte
# 24        219165.0  Nordeste         1.802295  Grande Porte
# 208       144842.0  Nordeste         0.718024  Grande Porte
# 239       140228.0  Nordeste         2.110848  Grande Porte
# 271       247922.0  Nordeste         0.310582  Grande Porte
# 329       102238.0  Nordeste         0.704239  Grande Porte
# ...            ...       ...              ...           ...
# 1023081   265713.0  Nordeste         0.218281  Grande Porte
# 1023082   821978.0  Nordeste         0.411203  Grande Porte
# 1023091   207052.0  Nordeste         0.159380  Grande Porte
# 1024023   582274.0  Nordeste         0.424199  Grande Porte
# 1024067   163960.0  Nordeste         0.463528  Grande Porte
#
# [9588 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-20-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.918341
# 2010-02-28            0.901855
# 2010-03-31            0.899480
# 2010-04-30            0.876811
# 2010-05-31            0.922995
# ...                        ...
# 2023-12-31            0.696470
# 2024-01-31            0.703354
# 2024-02-29            0.692888
# 2024-03-31            0.758475
# 2024-04-30            0.790180
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.918341
# 2010-02-28            0.901855
# 2010-03-31            0.899480
# 2010-04-30            0.876811
# 2010-05-31            0.922995
# ...                        ...
# 2023-12-31            0.696470
# 2024-01-31            0.703354
# 2024-02-29            0.692888
# 2024-03-31            0.758475
# 2024-04-30            0.790180
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - loss: 0.2354 - mean_squared_error: 0.2354
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.1331 - mean_squared_error: 0.1331
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - loss: 0.0228 - mean_squared_error: 0.0228
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0226 - mean_squared_error: 0.0226
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0246 - mean_squared_error: 0.0246
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0212 - mean_squared_error: 0.0212
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 0.0313 - mean_squared_error: 0.0313
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - loss: 0.0230 - mean_squared_error: 0.0230
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 279ms/step - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - loss: 0.0220 - mean_squared_error: 0.0220
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 450ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 310ms/step - loss: 0.0244 - mean_squared_error: 0.0244
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 273ms/step - loss: 0.0243 - mean_squared_error: 0.0243
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0213 - mean_squared_error: 0.0213
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 435ms/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 338ms/step - loss: 0.0177 - mean_squared_error: 0.0177
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0212 - mean_squared_error: 0.0212
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 350ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 463ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 447ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 439ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 324ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0136 - mean_squared_error: 0.0136
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - loss: 0.0206 - mean_squared_error: 0.0206
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 327ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 370ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 430ms/step - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 347ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 455ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 278ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 459ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 465ms/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 304ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 465ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - loss: 0.0069 - mean_squared_error: 0.0069

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.601031    0.671559
# 2022-02-28  0.631028    0.588703
# 2022-03-31  0.625107    0.702387
# 2022-04-30  0.643461    0.702254
# 2022-05-31  0.674707    0.726767
# 2022-06-30  0.698740    0.705987
# 2022-07-31  0.700120    0.721107
# 2022-08-31  0.699520    0.767824
# 2022-09-30  0.720505    0.732706
# 2022-10-31  0.729670    0.678665
# 2022-11-30  0.705719    0.676071
# 2022-12-31  0.683662    0.709078
# 2023-01-31  0.697098    0.687588
# 2023-02-28  0.709505    0.712596
# 2023-03-31  0.720026    0.737215
# 2023-04-30  0.732348    0.751014
# 2023-05-31  0.745309    0.803576
# 2023-06-30  0.766851    0.799149
# 2023-07-31  0.779894    0.852136
# 2023-08-31  0.796391    0.790289
# 2023-09-30  0.787726    0.747055
# 2023-10-31  0.758390    0.758502
# 2023-11-30  0.748420    0.741647
# 2023-12-31  0.752234    0.696470
# 2024-01-31  0.739879    0.703354
# 2024-02-29  0.730347    0.692888
# 2024-03-31  0.727683    0.758475
# 2024-04-30  0.753005    0.790180

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.0017376244

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.04168482

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 0.9097543283415281

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_grande_porte_sem_dados_inputados(2010)_nordeste.csv', index=False)
