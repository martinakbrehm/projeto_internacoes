# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
# Dicionário de estados para regiões
estado_para_regiao = {
    'RS': 'Sul', 'SC': 'Sul', 'PR': 'Sul',
    'SP': 'Sudeste', 'RJ': 'Sudeste', 'ES': 'Sudeste', 'MG': 'Sudeste',
    'BA': 'Nordeste', 'SE': 'Nordeste', 'AL': 'Nordeste', 'PE': 'Nordeste', 'PB': 'Nordeste',
    'RN': 'Nordeste', 'CE': 'Nordeste', 'PI': 'Nordeste', 'MA': 'Nordeste',
    'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'GO': 'Centro-Oeste', 'DF': 'Centro-Oeste',
    'AM': 'Norte', 'RR': 'Norte', 'AP': 'Norte', 'PA': 'Norte', 'TO': 'Norte', 'RO': 'Norte', 'AC': 'Norte'
}

# Adicionar a coluna de Região
dataset['Região'] = dataset['UF'].map(estado_para_regiao)

# %%
#Filtro por região
dataset = dataset[dataset['Região'] == 'Sul']

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)
# Out:
# <ipython-input-12-5efc2a6ac78c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)
# Out:
# <ipython-input-13-52a9ceda9164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF            Município  populacao  \
# 3194                   30    2010-01-01  PR               ABATIÁ     7919.0
# 3195                    2    2010-01-01  PR         ADRIANÓPOLIS     6503.0
# 3196                    4    2010-01-01  PR        AGUDOS DO SUL     8435.0
# 3197                  125    2010-01-01  PR  ALMIRANTE TAMANDARÉ   105267.0
# 3198                   23    2010-01-01  PR   ALTAMIRA DO PARANÁ     4392.0
# ...                   ...           ...  ..                  ...        ...
# 1024016                 3    2024-04-01  SC            WITMARSUM     3660.0
# 1024017                22    2024-04-01  SC              XANXERÊ    44867.0
# 1024018                18    2024-04-01  SC            XAVANTINA     4211.0
# 1024019                30    2024-04-01  SC                XAXIM    26144.0
# 1024020                 5    2024-04-01  SC               ZORTÉA     3041.0
#
#         Região  taxa_internacao             Porte
# 3194       Sul         3.788357   Pequeno Porte I
# 3195       Sul         0.307550   Pequeno Porte I
# 3196       Sul         0.474215   Pequeno Porte I
# 3197       Sul         1.187457      Grande Porte
# 3198       Sul         5.236794   Pequeno Porte I
# ...        ...              ...               ...
# 1024016    Sul         0.819672   Pequeno Porte I
# 1024017    Sul         0.490338  Pequeno Porte II
# 1024018    Sul         4.274519   Pequeno Porte I
# 1024019    Sul         1.147491  Pequeno Porte II
# 1024020    Sul         1.644196   Pequeno Porte I
#
# [219144 rows x 8 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Grande Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF            Município  populacao  \
# 3197                  125    2010-01-01  PR  ALMIRANTE TAMANDARÉ   105267.0
# 3211                  146    2010-01-01  PR            APUCARANA   123336.0
# 3212                  201    2010-01-01  PR            ARAPONGAS   106232.0
# 3216                   54    2010-01-01  PR            ARAUCÁRIA   121504.0
# 3253                  142    2010-01-01  PR          CAMPO LARGO   114623.0
# ...                   ...           ...  ..                  ...        ...
# 1023861               170    2024-04-01  SC       JARAGUÁ DO SUL   145519.0
# 1023864               611    2024-04-01  SC            JOINVILLE   523903.0
# 1023868               181    2024-04-01  SC                LAGES   159351.0
# 1023908               197    2024-04-01  SC              PALHOÇA   139633.0
# 1023975               171    2024-04-01  SC             SÃO JOSÉ   213317.0
#
#         Região  taxa_internacao         Porte
# 3197       Sul         1.187457  Grande Porte
# 3211       Sul         1.183758  Grande Porte
# 3212       Sul         1.892085  Grande Porte
# 3216       Sul         0.444430  Grande Porte
# 3253       Sul         1.238844  Grande Porte
# ...        ...              ...           ...
# 1023861    Sul         1.168232  Grande Porte
# 1023864    Sul         1.166246  Grande Porte
# 1023868    Sul         1.135857  Grande Porte
# 1023908    Sul         1.410841  Grande Porte
# 1023975    Sul         0.801624  Grande Porte
#
# [8428 rows x 8 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-17-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.919748
# 2010-02-28            0.863875
# 2010-03-31            0.928953
# 2010-04-30            0.940161
# 2010-05-31            0.980524
# ...                        ...
# 2023-12-31            0.915377
# 2024-01-31            0.972909
# 2024-02-29            0.865420
# 2024-03-31            0.927097
# 2024-04-30            0.916645
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            0.919748
# 2010-02-28            0.863875
# 2010-03-31            0.928953
# 2010-04-30            0.940161
# 2010-05-31            0.980524
# ...                        ...
# 2023-12-31            0.915377
# 2024-01-31            0.972909
# 2024-02-29            0.865420
# 2024-03-31            0.927097
# 2024-04-30            0.916645
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 12s 374ms/step - loss: 0.1985 - mean_squared_error: 0.1985
# Epoch 2/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0925 - mean_squared_error: 0.0925
# Epoch 3/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0382 - mean_squared_error: 0.0382
# Epoch 4/100
# 9/9 [==============================] - 4s 412ms/step - loss: 0.0339 - mean_squared_error: 0.0339
# Epoch 5/100
# 9/9 [==============================] - 4s 443ms/step - loss: 0.0295 - mean_squared_error: 0.0295
# Epoch 6/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 7/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0321 - mean_squared_error: 0.0321
# Epoch 8/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0284 - mean_squared_error: 0.0284
# Epoch 9/100
# 9/9 [==============================] - 4s 414ms/step - loss: 0.0298 - mean_squared_error: 0.0298
# Epoch 10/100
# 9/9 [==============================] - 4s 440ms/step - loss: 0.0259 - mean_squared_error: 0.0259
# Epoch 11/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0267 - mean_squared_error: 0.0267
# Epoch 12/100
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0312 - mean_squared_error: 0.0312
# Epoch 13/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0290 - mean_squared_error: 0.0290
# Epoch 14/100
# 9/9 [==============================] - 4s 425ms/step - loss: 0.0287 - mean_squared_error: 0.0287
# Epoch 15/100
# 9/9 [==============================] - 4s 433ms/step - loss: 0.0340 - mean_squared_error: 0.0340
# Epoch 16/100
# 9/9 [==============================] - 3s 309ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Epoch 17/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 18/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0248 - mean_squared_error: 0.0248
# Epoch 19/100
# 9/9 [==============================] - 4s 421ms/step - loss: 0.0263 - mean_squared_error: 0.0263
# Epoch 20/100
# 9/9 [==============================] - 4s 443ms/step - loss: 0.0263 - mean_squared_error: 0.0263
# Epoch 21/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 22/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0266 - mean_squared_error: 0.0266
# Epoch 23/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0302 - mean_squared_error: 0.0302
# Epoch 24/100
# 9/9 [==============================] - 6s 732ms/step - loss: 0.0323 - mean_squared_error: 0.0323
# Epoch 25/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0313 - mean_squared_error: 0.0313
# Epoch 26/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0396 - mean_squared_error: 0.0396
# Epoch 27/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0374 - mean_squared_error: 0.0374
# Epoch 28/100
# 9/9 [==============================] - 3s 362ms/step - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 29/100
# 9/9 [==============================] - 4s 477ms/step - loss: 0.0290 - mean_squared_error: 0.0290
# Epoch 30/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Epoch 31/100
# 9/9 [==============================] - 3s 314ms/step - loss: 0.0279 - mean_squared_error: 0.0279
# Epoch 32/100
# 9/9 [==============================] - 3s 314ms/step - loss: 0.0280 - mean_squared_error: 0.0280
# Epoch 33/100
# 9/9 [==============================] - 3s 367ms/step - loss: 0.0261 - mean_squared_error: 0.0261
# Epoch 34/100
# 9/9 [==============================] - 4s 469ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Epoch 35/100
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Epoch 36/100
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0288 - mean_squared_error: 0.0288
# Epoch 37/100
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 38/100
# 9/9 [==============================] - 3s 345ms/step - loss: 0.0258 - mean_squared_error: 0.0258
# Epoch 39/100
# 9/9 [==============================] - 4s 471ms/step - loss: 0.0258 - mean_squared_error: 0.0258
# Epoch 40/100
# 9/9 [==============================] - 3s 340ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 41/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0276 - mean_squared_error: 0.0276
# Epoch 42/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0285 - mean_squared_error: 0.0285
# Epoch 43/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0267 - mean_squared_error: 0.0267
# Epoch 44/100
# 9/9 [==============================] - 4s 473ms/step - loss: 0.0271 - mean_squared_error: 0.0271
# Epoch 45/100
# 9/9 [==============================] - 3s 324ms/step - loss: 0.0298 - mean_squared_error: 0.0298
# Epoch 46/100
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0257 - mean_squared_error: 0.0257
# Epoch 47/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0261 - mean_squared_error: 0.0261
# Epoch 48/100
# 9/9 [==============================] - 3s 307ms/step - loss: 0.0250 - mean_squared_error: 0.0250
# Epoch 49/100
# 9/9 [==============================] - 4s 451ms/step - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 50/100
# 9/9 [==============================] - 3s 349ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 51/100
# 9/9 [==============================] - 3s 312ms/step - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 52/100
# 9/9 [==============================] - 3s 317ms/step - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 53/100
# 9/9 [==============================] - 3s 342ms/step - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 54/100
# 9/9 [==============================] - 4s 440ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 55/100
# 9/9 [==============================] - 3s 349ms/step - loss: 0.0228 - mean_squared_error: 0.0228
# Epoch 56/100
# 9/9 [==============================] - 3s 312ms/step - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 57/100
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 58/100
# 9/9 [==============================] - 3s 331ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 59/100
# 9/9 [==============================] - 4s 463ms/step - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 60/100
# 9/9 [==============================] - 3s 338ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 61/100
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 62/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 63/100
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 64/100
# 9/9 [==============================] - 4s 473ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 65/100
# 9/9 [==============================] - 3s 327ms/step - loss: 0.0147 - mean_squared_error: 0.0147
# Epoch 66/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 67/100
# 9/9 [==============================] - 3s 312ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 68/100
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 69/100
# 9/9 [==============================] - 4s 466ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 70/100
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 71/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 72/100
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 73/100
# 9/9 [==============================] - 3s 355ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 74/100
# 9/9 [==============================] - 4s 486ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 75/100
# 9/9 [==============================] - 3s 319ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 76/100
# 9/9 [==============================] - 2s 266ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 77/100
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 78/100
# 9/9 [==============================] - 3s 357ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 79/100
# 9/9 [==============================] - 4s 444ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 80/100
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 81/100
# 9/9 [==============================] - 3s 310ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 82/100
# 9/9 [==============================] - 2s 264ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 83/100
# 9/9 [==============================] - 3s 297ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 84/100
# 9/9 [==============================] - 4s 411ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 85/100
# 9/9 [==============================] - 3s 366ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 86/100
# 9/9 [==============================] - 2s 272ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 87/100
# 9/9 [==============================] - 3s 312ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 88/100
# 9/9 [==============================] - 3s 308ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 89/100
# 9/9 [==============================] - 4s 406ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 90/100
# 9/9 [==============================] - 4s 426ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 91/100
# 9/9 [==============================] - 2s 266ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 92/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 93/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 94/100
# 9/9 [==============================] - 3s 338ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 95/100
# 9/9 [==============================] - 4s 469ms/step - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 96/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 97/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 98/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 99/100
# 9/9 [==============================] - 3s 284ms/step - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 100/100
# 9/9 [==============================] - 4s 468ms/step - loss: 0.0086 - mean_squared_error: 0.0086

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.735750    0.780451
# 2022-02-28  0.753677    0.745699
# 2022-03-31  0.750591    0.822629
# 2022-04-30  0.766793    0.853706
# 2022-05-31  0.798735    0.904179
# 2022-06-30  0.833265    0.924850
# 2022-07-31  0.853068    0.960914
# 2022-08-31  0.866006    0.962051
# 2022-09-30  0.866414    0.906029
# 2022-10-31  0.838331    0.979010
# 2022-11-30  0.841040    0.886315
# 2022-12-31  0.826800    0.896054
# 2023-01-31  0.815632    0.870515
# 2023-02-28  0.813257    0.846913
# 2023-03-31  0.816186    0.893926
# 2023-04-30  0.845750    0.929499
# 2023-05-31  0.891992    1.007223
# 2023-06-30  0.946467    0.955412
# 2023-07-31  0.942226    0.968259
# 2023-08-31  0.917449    1.017025
# 2023-09-30  0.920096    0.949913
# 2023-10-31  0.898897    0.953358
# 2023-11-30  0.869918    0.922249
# 2023-12-31  0.853355    0.915377
# 2024-01-31  0.849748    0.972909
# 2024-02-29  0.887519    0.865420
# 2024-03-31  0.876955    0.927097
# 2024-04-30  0.883158    0.916645

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.005509252

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.07422434

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 1.4959534950154336

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_grande_porte_sem_dados_inputados(2010)_sul.csv', index=False)
