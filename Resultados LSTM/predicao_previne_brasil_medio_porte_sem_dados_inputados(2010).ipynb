# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao  \
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
#          taxa_internacao             Porte
# 0               1.070255   Pequeno Porte I
# 1               1.104972   Pequeno Porte I
# 2               2.150056  Pequeno Porte II
# 3               0.226296   Pequeno Porte I
# 4               0.435777   Pequeno Porte I
# ...                  ...               ...
# 1024875         1.212016  Pequeno Porte II
# 1024876         0.621891   Pequeno Porte I
# 1024877         0.466853   Pequeno Porte I
# 1024878         1.069900   Pequeno Porte I
# 1024879         1.790434   Pequeno Porte I
#
# [1024880 rows x 7 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Médio Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF            Município  populacao  \
# 5                     249    2010-01-01  AC      CRUZEIRO DO SUL    81907.0
# 36                     54    2010-01-01  AL         CAMPO ALEGRE    52041.0
# 45                     55    2010-01-01  AL             CORURIPE    53387.0
# 88                     64    2010-01-01  AL  PALMEIRA DOS ÍNDIOS    72064.0
# 94                    138    2010-01-01  AL               PENEDO    61834.0
# ...                   ...           ...  ..                  ...        ...
# 1024719               133    2024-04-01  SP              UBATUBA    80781.0
# 1024734                59    2024-04-01  SP              VINHEDO    65209.0
# 1024739                69    2024-04-01  SP          VOTUPORANGA    86820.0
# 1024799                75    2024-04-01  TO               GURUPI    78394.0
# 1024845                56    2024-04-01  TO       PORTO NACIONAL    50196.0
#
#          taxa_internacao        Porte
# 5               3.040033  Médio Porte
# 36              1.037643  Médio Porte
# 45              1.030213  Médio Porte
# 88              0.888099  Médio Porte
# 94              2.231782  Médio Porte
# ...                  ...          ...
# 1024719         1.646427  Médio Porte
# 1024734         0.904783  Médio Porte
# 1024739         0.794748  Médio Porte
# 1024799         0.956706  Médio Porte
# 1024845         1.115627  Médio Porte
#
# [58368 rows x 7 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-15-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262302
# 2010-02-28            1.205797
# 2010-03-31            1.276683
# 2010-04-30            1.215884
# 2010-05-31            1.215052
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2010-1-1':'2024-04-30']

# %%
plt.plot(time_series)

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262302
# 2010-02-28            1.205797
# 2010-03-31            1.276683
# 2010-04-30            1.215884
# 2010-05-31            1.215052
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [172 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 160

# %%
x_train, y_train = x[:132], y[:132]
x_test, y_test = x[132:], y[132:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 10s 238ms/step - loss: 0.1552 - mean_squared_error: 0.1552
# Epoch 2/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0582 - mean_squared_error: 0.0582
# Epoch 3/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0286 - mean_squared_error: 0.0286
# Epoch 4/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 5/100
# 9/9 [==============================] - 3s 361ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 6/100
# 9/9 [==============================] - 3s 315ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 7/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 8/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 9/100
# 9/9 [==============================] - 2s 229ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 10/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 11/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 12/100
# 9/9 [==============================] - 3s 366ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 13/100
# 9/9 [==============================] - 2s 234ms/step - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 14/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 15/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 16/100
# 9/9 [==============================] - 2s 237ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 17/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.0133 - mean_squared_error: 0.0133
# Epoch 18/100
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 19/100
# 9/9 [==============================] - 3s 292ms/step - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 20/100
# 9/9 [==============================] - 2s 233ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 21/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 22/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 23/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 24/100
# 9/9 [==============================] - 3s 345ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 25/100
# 9/9 [==============================] - 3s 341ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 26/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 27/100
# 9/9 [==============================] - 2s 225ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 28/100
# 9/9 [==============================] - 2s 226ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 29/100
# 9/9 [==============================] - 2s 229ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 30/100
# 9/9 [==============================] - 2s 278ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 31/100
# 9/9 [==============================] - 3s 364ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 32/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 33/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 34/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 35/100
# 9/9 [==============================] - 2s 233ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 36/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 37/100
# 9/9 [==============================] - 3s 369ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 38/100
# 9/9 [==============================] - 3s 316ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 39/100
# 9/9 [==============================] - 2s 236ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 40/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 41/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 42/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 43/100
# 9/9 [==============================] - 3s 328ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 44/100
# 9/9 [==============================] - 3s 364ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 45/100
# 9/9 [==============================] - 2s 234ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 46/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 47/100
# 9/9 [==============================] - 2s 237ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 48/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 49/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 50/100
# 9/9 [==============================] - 3s 360ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 51/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 52/100
# 9/9 [==============================] - 2s 238ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 53/100
# 9/9 [==============================] - 2s 236ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 54/100
# 9/9 [==============================] - 2s 234ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 55/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 56/100
# 9/9 [==============================] - 3s 361ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 57/100
# 9/9 [==============================] - 3s 294ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 58/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 59/100
# 9/9 [==============================] - 2s 233ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 60/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 61/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 62/100
# 9/9 [==============================] - 3s 346ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 63/100
# 9/9 [==============================] - 3s 345ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 64/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 65/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 66/100
# 9/9 [==============================] - 2s 225ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 67/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 68/100
# 9/9 [==============================] - 2s 282ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 69/100
# 9/9 [==============================] - 3s 357ms/step - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 70/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 71/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 72/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 73/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 74/100
# 9/9 [==============================] - 2s 235ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 75/100
# 9/9 [==============================] - 3s 354ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 76/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 77/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 78/100
# 9/9 [==============================] - 2s 229ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 79/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 80/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 81/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 82/100
# 9/9 [==============================] - 3s 357ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 83/100
# 9/9 [==============================] - 2s 233ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 84/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 85/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 86/100
# 9/9 [==============================] - 2s 227ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 87/100
# 9/9 [==============================] - 2s 238ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 88/100
# 9/9 [==============================] - 3s 346ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 89/100
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 90/100
# 9/9 [==============================] - 2s 225ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 91/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 92/100
# 9/9 [==============================] - 2s 236ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 93/100
# 9/9 [==============================] - 2s 232ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 94/100
# 9/9 [==============================] - 3s 327ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 95/100
# 9/9 [==============================] - 3s 357ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 96/100
# 9/9 [==============================] - 2s 230ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 97/100
# 9/9 [==============================] - 2s 228ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 98/100
# 9/9 [==============================] - 2s 237ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 99/100
# 9/9 [==============================] - 2s 231ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 100/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.0058 - mean_squared_error: 0.0058

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.741617    0.806979
# 2022-02-28  0.757427    0.738610
# 2022-03-31  0.750600    0.846133
# 2022-04-30  0.767388    0.867756
# 2022-05-31  0.806639    0.917178
# 2022-06-30  0.848829    0.911903
# 2022-07-31  0.867200    0.917154
# 2022-08-31  0.864260    0.939364
# 2022-09-30  0.864526    0.908139
# 2022-10-31  0.863329    0.906842
# 2022-11-30  0.860759    0.887028
# 2022-12-31  0.853995    0.870371
# 2023-01-31  0.843671    0.877790
# 2023-02-28  0.839563    0.857721
# 2023-03-31  0.837294    0.924976
# 2023-04-30  0.855203    0.931383
# 2023-05-31  0.879871    0.992631
# 2023-06-30  0.909262    0.975985
# 2023-07-31  0.922941    0.989791
# 2023-08-31  0.923651    0.963418
# 2023-09-30  0.913322    0.922492
# 2023-10-31  0.892539    0.923246
# 2023-11-30  0.878108    0.921506
# 2023-12-31  0.877889    0.890539
# 2024-01-31  0.874917    0.890174
# 2024-02-29  0.867019    0.848012
# 2024-03-31  0.847087    0.911118
# 2024-04-30  0.849384    0.839982

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.0035345892

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.05945241

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 1.3835584839769344

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_medio_porte_sem_dados_inputados(2010).csv', index=False)
