# %% [markdown]
# ##Configurações

# %%
# !pip install scikeras==0.12.0
# !pip install keras==2.15.0
# !pip install tensorflow
# Out:
# Collecting scikeras==0.12.0
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (24.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras==0.12.0) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras==0.12.0) (3.5.0)
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Metodos Para Calcular o Theils U Coefficient
def division(measure, previousI):
  return measure / previousI

def power(measure):
  return np.power(measure, 2)

def summation(measure):
  return np.sum(measure)

def mean(N, measure):
  return (1/N) * measure

def sqrt(measure):
  return np.sqrt(measure)

def theil_u2(y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    N = len(y_true)

    subtractionNumerator = y_pred[1:] - y_true[1:]
    divisionNumerator = division(subtractionNumerator, y_true[:-1])
    powerNumerator = power(divisionNumerator)
    summationNumerator = summation(powerNumerator)
    meanNumerator = mean(N, summationNumerator)
    numerator = sqrt(meanNumerator)

    subtractionDenominator = y_true[1:] - y_true[:-1]
    powerDenominator = power(division(subtractionDenominator, y_true[:-1]))
    denominator = sqrt(mean(N, summation(powerDenominator)))

    theilU2 = numerator / denominator

    return theilU2

# %% [markdown]
# ## Modelo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Projeto Internações/Preparação dos dados/dataset_internacoes_completo.csv')

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
# [1024880 rows x 5 columns]

# %%
dataset['populacao'].dtype
# Out:
# dtype('float64')

# %%
def porte(populacao):
  if populacao <= 20000:
    return 'Pequeno Porte I'
  elif populacao >= 20001 and populacao <= 50000 :
    return 'Pequeno Porte II'
  elif populacao >= 50001 and populacao <= 100000:
    return 'Médio Porte'
  elif populacao >= 100001 and populacao <= 900000:
    return 'Grande Porte'
  elif populacao >= 900001:
    return 'Metrópole'

# %%
def taxa_internacao (row):
  return row['Qtd. internacoes']*1000/row['populacao']

# %%
dataset['taxa_internacao'] = dataset.apply(taxa_internacao, axis =1)

# %%
dataset['Porte'] = dataset['populacao'].apply(porte)

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF       Município  populacao  \
# 0                      14    2010-01-01  AC      ACRELÂNDIA    13081.0
# 1                       7    2010-01-01  AC    ASSIS BRASIL     6335.0
# 2                      48    2010-01-01  AC       BRASILÉIA    22325.0
# 3                       2    2010-01-01  AC          BUJARI     8838.0
# 4                       4    2010-01-01  AC        CAPIXABA     9179.0
# ...                   ...           ...  ..             ...        ...
# 1024875                28    2024-04-01  TO  TOCANTINÓPOLIS    23102.0
# 1024876                 1    2024-04-01  TO        TUPIRAMA     1608.0
# 1024877                 1    2024-04-01  TO      TUPIRATINS     2142.0
# 1024878                12    2024-04-01  TO    WANDERLÂNDIA    11216.0
# 1024879                21    2024-04-01  TO         XAMBIOÁ    11729.0
#
#          taxa_internacao             Porte
# 0               1.070255   Pequeno Porte I
# 1               1.104972   Pequeno Porte I
# 2               2.150056  Pequeno Porte II
# 3               0.226296   Pequeno Porte I
# 4               0.435777   Pequeno Porte I
# ...                  ...               ...
# 1024875         1.212016  Pequeno Porte II
# 1024876         0.621891   Pequeno Porte I
# 1024877         0.466853   Pequeno Porte I
# 1024878         1.069900   Pequeno Porte I
# 1024879         1.790434   Pequeno Porte I
#
# [1024880 rows x 7 columns]

# %% [markdown]
# Filtro

# %%
dataset = dataset[dataset['Porte'] == 'Médio Porte']

# %%
dataset
# Out:
#          Qtd. internacoes Data completa  UF            Município  populacao  \
# 5                     249    2010-01-01  AC      CRUZEIRO DO SUL    81907.0
# 36                     54    2010-01-01  AL         CAMPO ALEGRE    52041.0
# 45                     55    2010-01-01  AL             CORURIPE    53387.0
# 88                     64    2010-01-01  AL  PALMEIRA DOS ÍNDIOS    72064.0
# 94                    138    2010-01-01  AL               PENEDO    61834.0
# ...                   ...           ...  ..                  ...        ...
# 1024719               133    2024-04-01  SP              UBATUBA    80781.0
# 1024734                59    2024-04-01  SP              VINHEDO    65209.0
# 1024739                69    2024-04-01  SP          VOTUPORANGA    86820.0
# 1024799                75    2024-04-01  TO               GURUPI    78394.0
# 1024845                56    2024-04-01  TO       PORTO NACIONAL    50196.0
#
#          taxa_internacao        Porte
# 5               3.040033  Médio Porte
# 36              1.037643  Médio Porte
# 45              1.030213  Médio Porte
# 88              0.888099  Médio Porte
# 94              2.231782  Médio Porte
# ...                  ...          ...
# 1024719         1.646427  Médio Porte
# 1024734         0.904783  Médio Porte
# 1024739         0.794748  Médio Porte
# 1024799         0.956706  Médio Porte
# 1024845         1.115627  Médio Porte
#
# [58368 rows x 7 columns]

# %%
time_series = dataset[['Data completa', 'taxa_internacao']]
time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])
# Out:
# <ipython-input-15-8980fe5bf9f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_series['Data completa'] = pd.to_datetime(time_series['Data completa'])

# %%
time_series = time_series.set_index('Data completa').resample('M').mean()

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2010-01-31            1.262302
# 2010-02-28            1.205797
# 2010-03-31            1.276683
# 2010-04-30            1.215884
# 2010-05-31            1.215052
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [172 rows x 1 columns]

# %%
time_series = time_series['2016-1-1':'2024-04-30']

# %%
time_series
# Out:
#                taxa_internacao
# Data completa
# 2016-01-31            0.911740
# 2016-02-29            0.943667
# 2016-03-31            0.964830
# 2016-04-30            0.951924
# 2016-05-31            0.944934
# ...                        ...
# 2023-12-31            0.890539
# 2024-01-31            0.890174
# 2024-02-29            0.848012
# 2024-03-31            0.911118
# 2024-04-30            0.839982
#
# [100 rows x 1 columns]

# %%
train_data= time_series.values

#Normaliza os Dados
normalizer = MinMaxScaler(feature_range=(0,1))
train_data = normalizer.fit_transform(train_data)

#Cria os Arrays No Formato Certo
x = []
y = []
for i in range(12, len(train_data)):
  x.append(train_data[i-12:i, 0])
  y.append(train_data[i,0])
x, y = np.array(x), np.array(y)
x = np.reshape(x, (x.shape[0], x.shape[1],1))

#Converte os Dados Para Float
x = np.asarray(x).astype('float32')
y = np.asarray(y).astype('float32')

# %%
len(x)
# Out:
# 88

# %%
x_train, y_train = x[:60], y[:60]
x_test, y_test = x[60:], y[60:]

# %%
len(x_test)
# Out:
# 28

# %%
#Cria o Modelo De Rede Neural
dropout_val = 0.2
regressor = Sequential()
regressor.add(LSTM(units = 800, return_sequences = True, input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 300, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(dropout_val))

regressor.add(LSTM(units = 200))
regressor.add(Dropout(dropout_val))

regressor.add(Dense(units = 1, activation ='linear'))

regressor.compile(optimizer = 'adam', loss= 'mean_squared_error',
                  metrics = ['mean_squared_error'])


regressor.fit(x_train, y_train, epochs = 100, batch_size=16)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 11s 323ms/step - loss: 0.3435 - mean_squared_error: 0.3435
# Epoch 2/100
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1144 - mean_squared_error: 0.1144
# Epoch 3/100
# 4/4 [==============================] - 1s 310ms/step - loss: 0.1794 - mean_squared_error: 0.1794
# Epoch 4/100
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0940 - mean_squared_error: 0.0940
# Epoch 5/100
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0624 - mean_squared_error: 0.0624
# Epoch 6/100
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0757 - mean_squared_error: 0.0757
# Epoch 7/100
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0622 - mean_squared_error: 0.0622
# Epoch 8/100
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0630 - mean_squared_error: 0.0630
# Epoch 9/100
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0547 - mean_squared_error: 0.0547
# Epoch 10/100
# 4/4 [==============================] - 2s 421ms/step - loss: 0.0570 - mean_squared_error: 0.0570
# Epoch 11/100
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0551 - mean_squared_error: 0.0551
# Epoch 12/100
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0537 - mean_squared_error: 0.0537
# Epoch 13/100
# 4/4 [==============================] - 1s 269ms/step - loss: 0.0516 - mean_squared_error: 0.0516
# Epoch 14/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0477 - mean_squared_error: 0.0477
# Epoch 15/100
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0560 - mean_squared_error: 0.0560
# Epoch 16/100
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0575 - mean_squared_error: 0.0575
# Epoch 17/100
# 4/4 [==============================] - 1s 270ms/step - loss: 0.0619 - mean_squared_error: 0.0619
# Epoch 18/100
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0504 - mean_squared_error: 0.0504
# Epoch 19/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0510 - mean_squared_error: 0.0510
# Epoch 20/100
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0465 - mean_squared_error: 0.0465
# Epoch 21/100
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0499 - mean_squared_error: 0.0499
# Epoch 22/100
# 4/4 [==============================] - 2s 531ms/step - loss: 0.0492 - mean_squared_error: 0.0492
# Epoch 23/100
# 4/4 [==============================] - 2s 597ms/step - loss: 0.0477 - mean_squared_error: 0.0477
# Epoch 24/100
# 4/4 [==============================] - 2s 373ms/step - loss: 0.0488 - mean_squared_error: 0.0488
# Epoch 25/100
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0559 - mean_squared_error: 0.0559
# Epoch 26/100
# 4/4 [==============================] - 2s 406ms/step - loss: 0.0536 - mean_squared_error: 0.0536
# Epoch 27/100
# 4/4 [==============================] - 2s 422ms/step - loss: 0.0483 - mean_squared_error: 0.0483
# Epoch 28/100
# 4/4 [==============================] - 1s 402ms/step - loss: 0.0459 - mean_squared_error: 0.0459
# Epoch 29/100
# 4/4 [==============================] - 1s 275ms/step - loss: 0.0416 - mean_squared_error: 0.0416
# Epoch 30/100
# 4/4 [==============================] - 1s 276ms/step - loss: 0.0457 - mean_squared_error: 0.0457
# Epoch 31/100
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0443 - mean_squared_error: 0.0443
# Epoch 32/100
# 4/4 [==============================] - 1s 395ms/step - loss: 0.0428 - mean_squared_error: 0.0428
# Epoch 33/100
# 4/4 [==============================] - 2s 552ms/step - loss: 0.0391 - mean_squared_error: 0.0391
# Epoch 34/100
# 4/4 [==============================] - 2s 529ms/step - loss: 0.0371 - mean_squared_error: 0.0371
# Epoch 35/100
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0358 - mean_squared_error: 0.0358
# Epoch 36/100
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 37/100
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0404 - mean_squared_error: 0.0404
# Epoch 38/100
# 4/4 [==============================] - 1s 301ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Epoch 39/100
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0492 - mean_squared_error: 0.0492
# Epoch 40/100
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0458 - mean_squared_error: 0.0458
# Epoch 41/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0378 - mean_squared_error: 0.0378
# Epoch 42/100
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0390 - mean_squared_error: 0.0390
# Epoch 43/100
# 4/4 [==============================] - 1s 354ms/step - loss: 0.0425 - mean_squared_error: 0.0425
# Epoch 44/100
# 4/4 [==============================] - 2s 597ms/step - loss: 0.0406 - mean_squared_error: 0.0406
# Epoch 45/100
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0549 - mean_squared_error: 0.0549
# Epoch 46/100
# 4/4 [==============================] - 2s 426ms/step - loss: 0.0480 - mean_squared_error: 0.0480
# Epoch 47/100
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Epoch 48/100
# 4/4 [==============================] - 1s 273ms/step - loss: 0.0384 - mean_squared_error: 0.0384
# Epoch 49/100
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Epoch 50/100
# 4/4 [==============================] - 1s 372ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Epoch 51/100
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 52/100
# 4/4 [==============================] - 2s 377ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Epoch 53/100
# 4/4 [==============================] - 2s 376ms/step - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 54/100
# 4/4 [==============================] - 2s 499ms/step - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 55/100
# 4/4 [==============================] - 2s 413ms/step - loss: 0.0287 - mean_squared_error: 0.0287
# Epoch 56/100
# 4/4 [==============================] - 2s 501ms/step - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 57/100
# 4/4 [==============================] - 2s 433ms/step - loss: 0.0300 - mean_squared_error: 0.0300
# Epoch 58/100
# 4/4 [==============================] - 1s 274ms/step - loss: 0.0261 - mean_squared_error: 0.0261
# Epoch 59/100
# 4/4 [==============================] - 1s 360ms/step - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 60/100
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 61/100
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0272 - mean_squared_error: 0.0272
# Epoch 62/100
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0267 - mean_squared_error: 0.0267
# Epoch 63/100
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0286 - mean_squared_error: 0.0286
# Epoch 64/100
# 4/4 [==============================] - 1s 357ms/step - loss: 0.0308 - mean_squared_error: 0.0308
# Epoch 65/100
# 4/4 [==============================] - 2s 496ms/step - loss: 0.0325 - mean_squared_error: 0.0325
# Epoch 66/100
# 4/4 [==============================] - 2s 504ms/step - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 67/100
# 4/4 [==============================] - 2s 509ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Epoch 68/100
# 4/4 [==============================] - 2s 360ms/step - loss: 0.0252 - mean_squared_error: 0.0252
# Epoch 69/100
# 4/4 [==============================] - 1s 359ms/step - loss: 0.0251 - mean_squared_error: 0.0251
# Epoch 70/100
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0230 - mean_squared_error: 0.0230
# Epoch 71/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 72/100
# 4/4 [==============================] - 1s 327ms/step - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 73/100
# 4/4 [==============================] - 1s 324ms/step - loss: 0.0189 - mean_squared_error: 0.0189
# Epoch 74/100
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 75/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0210 - mean_squared_error: 0.0210
# Epoch 76/100
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 77/100
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0197 - mean_squared_error: 0.0197
# Epoch 78/100
# 4/4 [==============================] - 2s 431ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 79/100
# 4/4 [==============================] - 1s 331ms/step - loss: 0.0196 - mean_squared_error: 0.0196
# Epoch 80/100
# 4/4 [==============================] - 1s 360ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 81/100
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 82/100
# 4/4 [==============================] - 1s 268ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 83/100
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 84/100
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 85/100
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 86/100
# 4/4 [==============================] - 2s 416ms/step - loss: 0.0197 - mean_squared_error: 0.0197
# Epoch 87/100
# 4/4 [==============================] - 2s 492ms/step - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 88/100
# 4/4 [==============================] - 2s 492ms/step - loss: 0.0195 - mean_squared_error: 0.0195
# Epoch 89/100
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0223 - mean_squared_error: 0.0223
# Epoch 90/100
# 4/4 [==============================] - 1s 271ms/step - loss: 0.0245 - mean_squared_error: 0.0245
# Epoch 91/100
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 92/100
# 4/4 [==============================] - 1s 272ms/step - loss: 0.0189 - mean_squared_error: 0.0189
# Epoch 93/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 94/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0225 - mean_squared_error: 0.0225
# Epoch 95/100
# 4/4 [==============================] - 1s 324ms/step - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 96/100
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 97/100
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 98/100
# 4/4 [==============================] - 2s 505ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 99/100
# 4/4 [==============================] - 2s 546ms/step - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 100/100
# 4/4 [==============================] - 2s 533ms/step - loss: 0.0191 - mean_squared_error: 0.0191

# %%
y_test = y_test.reshape(-1, 1)
train_predictions = regressor.predict(x_test)
train_predictions = normalizer.inverse_transform(train_predictions)
y_test = normalizer.inverse_transform(y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
train_results = pd.DataFrame(zip(train_predictions, y_test), columns = ['previsao', 'valor_real'])
train_results['previsao'] = train_results['previsao'].apply(lambda x: x[0])
train_results['valor_real'] = train_results['valor_real'].apply(lambda x: x[0])
forecasts = train_results['previsao']
#train_results

# %%
start_date = "2022-1-31"
train_results['data'] = pd.date_range(start=start_date, periods=len(train_results), freq='M')
train_results.set_index('data', inplace=True)

# %%
train_results
# Out:
#             previsao  valor_real
# data
# 2022-01-31  0.756785    0.806979
# 2022-02-28  0.777647    0.738610
# 2022-03-31  0.786609    0.846133
# 2022-04-30  0.801427    0.867756
# 2022-05-31  0.832348    0.917178
# 2022-06-30  0.881846    0.911903
# 2022-07-31  0.920181    0.917154
# 2022-08-31  0.927996    0.939364
# 2022-09-30  0.917153    0.908139
# 2022-10-31  0.900510    0.906842
# 2022-11-30  0.889040    0.887028
# 2022-12-31  0.882216    0.870371
# 2023-01-31  0.873828    0.877790
# 2023-02-28  0.868527    0.857721
# 2023-03-31  0.859666    0.924976
# 2023-04-30  0.874015    0.931383
# 2023-05-31  0.903183    0.992631
# 2023-06-30  0.944347    0.975985
# 2023-07-31  0.972371    0.989791
# 2023-08-31  0.978168    0.963418
# 2023-09-30  0.962195    0.922492
# 2023-10-31  0.927952    0.923246
# 2023-11-30  0.898320    0.921506
# 2023-12-31  0.888187    0.890539
# 2024-01-31  0.889458    0.890174
# 2024-02-29  0.891427    0.848012
# 2024-03-31  0.876841    0.911118
# 2024-04-30  0.870260    0.839982

# %%
plt.plot(y_test, color='red', label = 'Real')
plt.plot(forecasts, color='blue', label = 'Previsto')
plt.xlabel('Meses')
plt.legend()
plt.show()

# %%
plt.plot(time_series, color='red', label = 'Real')
plt.plot(train_results['previsao'], color='blue', label = 'Previsto')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, forecasts)

# %%
mse
# Out:
# 0.001564999

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.03956007

# %%
tu = theil_u2(y_test, forecasts)

# %%
tu
# Out:
# 0.9201929121279367

# %%
# Salva o DataFrame em um arquivo CSV
train_results.to_csv('predicao_previne_brasil_medio_porte_sem_dados_inputados(2016).csv', index=False)
